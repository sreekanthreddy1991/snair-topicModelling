# %% [markdown]
# # Approach 1
#
# <ol>
#     <li>Find a vocabulary of 1000 most important words
#     <li>Build a vector of 1000 dimensions for each document - each dimension is the tfidf for that word in the vocabulary
#     <li>Use vector to and perform K-means clustering
# </ol>

# %%
import pandas as pd
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
df = pd.read_csv('incident_wide_descriptions.csv', header=0, encoding='ISO-8859-1')
df = df[['number', 'short_description']]

print(df.info())

df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193396 entries, 0 to 193395
# Data columns (total 2 columns):
# number               193396 non-null object
# short_description    193395 non-null object
# dtypes: object(2)
# memory usage: 3.0+ MB
# None
#        number                                  short_description
# 0  INC0229960                               Testing HRIT Request
# 1  INC0229990                             Testing HRIT Request 2
# 2  INC0230041                             Testing HRIT Request 3
# 3  INC0230756                             Testing HRIT Request 4
# 4  INC0160236     RE: ServiceNow IT Trouble Ticket Link Question
# 5  INC0156765  I get an error message in closing an epic fill...
# 6  INC0156736                          Unable to print from EPIC
# 7  INC0146421                 Add location option for a provider
# 8  INC0148808                     Printer will not feed properly
# 9  INC0149930  Add Darrell Misner (u6010696) to be able to bo...

# %%
description = ':;!?@#$%&*(){}[]\/.,""' + "''"

val = re.sub('[:;!?@#$%&*\(\)\[\]\{\}\./\\\,"]', "", description)
print(re.sub("[']", "", val))

# %%
df['short_description'] = df['short_description'].apply(lambda x: str(x).lower())
df['short_description'] = df['short_description'].apply(lambda x: re.sub("[']", "", re.sub('[;:!?@#$%&*\(\)\[\]\{\}\./\\\,"]', "", x)))

df.head(10)
# Out:
#        number                                  short_description
# 0  INC0229960                               testing hrit request
# 1  INC0229990                             testing hrit request 2
# 2  INC0230041                             testing hrit request 3
# 3  INC0230756                             testing hrit request 4
# 4  INC0160236      re servicenow it trouble ticket link question
# 5  INC0156765  i get an error message in closing an epic fill...
# 6  INC0156736                          unable to print from epic
# 7  INC0146421                 add location option for a provider
# 8  INC0148808                     printer will not feed properly
# 9  INC0149930  add darrell misner u6010696 to be able to book...

# %% [markdown]
# ### Vectorizing the input

# %%
documents = list(df['short_description'])
print(documents[:10])
# Out:
# ['testing hrit request', 'testing hrit request 2', 'testing hrit request 3', 'testing hrit request 4', 're servicenow it trouble ticket link question', 'i get an error message in closing an epic fill that says the file is icomplete phone 801-580-2765  dr meikle', 'unable to print from epic', 'add location option for a provider', 'printer will not feed properly', 'add darrell misner u6010696 to be able to book into provider slots']

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
X = vectorizer.fit_transform(documents)

# print(type(X))

# idf = vectorizer.idf_
# print(type(idf))

# print(idf[:10])

# print(type(vectorizer.get_feature_names()))
# print(vectorizer.get_feature_names()[:10])

display(dict(zip(vectorizer.get_feature_names(), idf)))
# Out:
# {'10': 6.5564351648557517,
#  '102': 8.0077143760650564,
#  '11': 8.0665548760879879,
#  '12': 8.0426016350654947,
#  '15': 8.2452466648313649,
#  '17': 7.9413917331339832,
#  '1st': 8.0787501491818077,
#  '20': 8.2672255715501404,
#  '2013': 8.2026870504125675,
#  '2016': 7.2509219303447541,
#  '2017': 7.1063922598848217,
#  '24': 8.1552205131736457,
#  '2fa': 6.7873059509908442,
#  '2nd': 7.8253928192711006,
#  '30': 8.0665548760879879,
#  '30757': 8.1035961477683376,
#  '360': 7.9202269219419392,
#  '365': 7.8112081842791445,
#  '3m': 7.696036798057059,
#  '3rd': 8.1618650558923136,
#  '581': 7.7743376484708167,
#  '585': 7.8018623218609067,
#  '587': 8.0192087554907907,
#  '801': 6.684816331503959,
#  'able': 5.9833326115682466,
#  'access': 3.8667588932491337,
#  'accessing': 6.663731213016888,
#  'account': 4.7101858200823212,
#  'accounts': 7.2063536108648778,
#  'acknowledge': 7.9963506174147403,
#  'acrobat': 7.9963506174147403,
#  'action': 7.6312368048301433,
#  'activate': 7.2114950103652964,
#  'activated': 8.0077143760650564,
#  'activation': 6.5004674045275026,
#  'active': 7.6794389066480209,
#  'activity': 7.9963506174147403,
#  'ad': 6.9740216334962613,
#  'add': 4.6892776781434851,
#  'added': 5.5601635128208242,
#  'adding': 6.6285885044237771,
#  'addition': 7.8791955252640768,
#  'additional': 7.237606154368982,
#  'address': 6.0039204527245342,
#  'adjust': 8.0973265347547425,
#  'admin': 4.7648988352024269,
#  'administer': 8.0250058731751164,
#  'administration': 7.8112081842791445,
#  'administrator': 7.9963506174147403,
#  'adobe': 6.3846553676789899,
#  'affecting': 8.2746605500376589,
#  'agent': 8.2237404596104007,
#  'alert': 7.8159140753165568,
#  'alias': 5.9297024271948136,
#  'allow': 6.9699648328006472,
#  'allowing': 7.9046421909252418,
#  'android': 8.1552205131736457,
#  'anesthesia': 8.0849040147561855,
#  'angel': 8.2026870504125675,
#  'anymore': 8.0308367934859106,
#  'app': 7.0197676552844648,
#  'appear': 8.1486198291422927,
#  'appears': 8.0020163549504169,
#  'application': 7.0699417553750008,
#  'applications': 6.6185669459627583,
#  'appointment': 7.5448792362979322,
#  'appointments': 8.1888937282802328,
#  'approval': 8.1420624285961338,
#  'approved': 8.2525194241604449,
#  'apps': 7.4104489672083922,
#  'archive': 7.2114950103652964,
#  'area': 6.9129188859236468,
#  'arup': 7.7608542981335296,
#  'asap': 7.4135985761112888,
#  'asked': 7.2270797413819947,
#  'asking': 7.7880052871994803,
#  'assign': 6.6114696840919969,
#  'assigned': 7.5520994842714195,
#  'assistance': 5.4587157333898144,
#  'assisted': 6.4426762794990937,
#  'attached': 6.8268639891599738,
#  'attachment': 8.0367019129383088,
#  'attending': 8.168554044043109,
#  'attention': 8.0849040147561855,
#  'attn': 6.7299601835203706,
#  'audio': 7.9202269219419392,
#  'audit': 7.859294370946782,
#  'authenticate': 6.7606820822786728,
#  'authentication': 6.4097708430566902,
#  'auto': 7.5703815291088681,
#  'available': 6.857142348466235,
#  'avaya': 6.578086890238791,
#  'avs': 8.1486198291422927,
#  'backup': 8.2672255715501404,
#  'bar': 7.9851145441478142,
#  'barcode': 7.127495035952558,
#  'basket': 8.1355477475749396,
#  'battery': 7.6835626238318833,
#  'bc': 7.4653900852396937,
#  'bca': 7.5165085391687168,
#  'bcma': 7.4957465477202874,
#  'behalf': 7.8741829834405328,
#  'bi': 7.7926029964481103,
#  'billing': 7.1563431902902161,
#  'biometric': 8.2672255715501404,
#  'biztalk': 8.1752880762244544,
#  'black': 7.0456311658743846,
#  'blank': 7.6391108612610497,
#  'bld': 7.237606154368982,
#  'block': 6.6329143943708999,
#  'blocked': 7.8943856907580523,
#  'blood': 8.2672255715501404,
#  'blue': 7.9202269219419392,
#  'board': 7.6003463178108053,
#  'boe': 7.3060322930552726,
#  'book': 7.9046421909252418,
#  'boot': 7.331858692615171,
#  'box': 6.4510746491979258,
#  'brenda': 7.1157163367599452,
#  'broken': 6.8268639891599738,
#  'browser': 7.6753321246953679,
#  'bsb': 7.859294370946782,
#  'build': 7.5965512468422531,
#  'building': 7.574078390990195,
#  'built': 8.1355477475749396,
#  'burn': 8.2026870504125675,
#  'business': 6.4804166074819411,
#  'busy': 8.2672255715501404,
#  'button': 7.4889205826498877,
#  'buttons': 8.1099053169616013,
#  'bypass': 5.3723372795956097,
#  'cable': 7.2780975157237187,
#  'cache': 7.9307533349289274,
#  'cactus': 8.1355477475749396,
#  'cadence': 7.1539071354923349,
#  'calendar': 6.6652226376035575,
#  'called': 7.4489152480361884,
#  'caller': 6.9699648328006472,
#  'calling': 8.2237404596104007,
#  'calls': 6.7220299278443933,
#  'campus': 7.5095398698526239,
#  'capture': 7.8691954419294934,
#  'card': 7.7431547210341289,
#  'cardiology': 8.1099053169616013,
#  'care': 6.3623578998734329,
#  'cart': 7.9307533349289274,
#  'cas': 8.1035961477683376,
#  'case': 7.4587675444792003,
#  'cash': 7.2753464823518286,
#  'cc': 7.9740033187227439,
#  'cell': 8.1752880762244544,
#  'center': 6.5418169643461974,
#  'certain': 8.1752880762244544,
#  'certificate': 7.9202269219419392,
#  'change': 5.0298551640457747,
#  'changed': 6.6372590789749113,
#  'changes': 7.0654774622463155,
#  'changing': 8.0973265347547425,
#  'charge': 5.788510892010061,
#  'charges': 7.8301660980237582,
#  'charging': 8.0020163549504169,
#  'chart': 6.2931445455281301,
#  'check': 6.5821993017918832,
#  'chrome': 7.6273229055090068,
#  'cis': 5.6626172888336557,
#  'cisco': 8.2746605500376589,
#  'citrix': 4.8019527389138172,
#  'claim': 7.756399947784149,
#  'claims': 8.2598454642525176,
#  'class': 8.0485363705853104,
#  'classifieds': 7.5412885681672037,
#  'clear': 7.9521445249102447,
#  'cleared': 7.2114950103652964,
#  'client': 5.6971611134218332,
#  'clients': 7.2244653608079235,
#  'clinic': 5.8876794374199664,
#  'clinical': 6.7427808719494324,
#  'clinics': 8.1486198291422927,
#  'clock': 7.8494903708501615,
#  'close': 7.2671385019339994,
#  'closed': 8.2973030267874179,
#  'cloud': 7.8892966212505806,
#  'cms': 8.1035961477683376,
#  'cnc': 7.9740033187227439,
#  'code': 5.5072156315172185,
#  'codes': 7.9740033187227439,
#  'coding': 8.0077143760650564,
#  'college': 7.8691954419294934,
#  'column': 8.1355477475749396,
#  'come': 8.0192087554907907,
#  'coming': 7.6079799426658763,
#  'complete': 7.3917568341962401,
#  'completed': 6.8939789258227249,
#  'compromised': 6.2449424437102525,
#  'computer': 4.3671252110788998,
#  'computers': 6.5699124577992327,
#  'conference': 7.1370189174638128,
#  'configuration': 6.737953831201116,
#  'configuring': 7.7519653507162838,
#  'connect': 5.8460347361482476,
#  'connected': 7.4135985761112888,
#  'connecting': 6.5093676539977663,
#  'connection': 6.1970864225326174,
#  'connections': 8.1752880762244544,
#  'connectivity': 7.1785389226820007,
#  'consult': 7.778872803636208,
#  'contact': 7.1322456387111552,
#  'copy': 8.091095985004106,
#  'copyright': 7.2919673635878688,
#  'cord': 7.756399947784149,
#  'correct': 7.2947645682089304,
#  'correctly': 7.2114950103652964,
#  'course': 8.0308367934859106,
#  'cpt': 8.3049658995329878,
#  'cr': 7.0240320540709229,
#  'crashing': 8.1355477475749396,
#  'create': 6.1026262215299969,
#  'created': 6.1639951679062897,
#  'creating': 8.0192087554907907,
#  'creation': 7.1636871645459745,
#  'creative': 8.2746605500376589,
#  'credentials': 7.4855249936487498,
#  'credit': 8.2237404596104007,
#  'critical': 7.3347699028226296,
#  'current': 7.6195407650669518,
#  'currently': 7.5060736618761377,
#  'cwi': 7.2891779615002905,
#  'daily': 8.1752880762244544,
#  'daniel': 8.1752880762244544,
#  'dashboard': 7.7044402088534385,
#  'data': 6.2941738816972448,
#  'database': 7.423107364080316,
#  'date': 7.0971543188998858,
#  'david': 8.2308579273792652,
#  'day': 7.3231755700417107,
#  'days': 7.8741829834405328,
#  'ddc': 7.8995007914248223,
#  'deactivate': 7.1612331755844076,
#  'deactivated': 8.2821512217668154,
#  'deactivation': 7.8943856907580523,
#  'dead': 7.6712421394438426,
#  'deceased': 7.3794867416044259,
#  'default': 6.9578922515663777,
#  'delete': 7.2270797413819947,
#  'deleted': 7.3856029686218614,
#  'delivery': 7.2671385019339994,
#  'denied': 8.0726339221643713,
#  'densley': 7.5557292523219983,
#  'dental': 7.9254762778280829,
#  'dep': 8.1226443427390329,
#  'department': 6.1558906660943506,
#  'departmental': 8.1162545446402614,
#  'departments': 7.859294370946782,
#  'dept': 7.237606154368982,
#  'description': 7.9467536762753683,
#  'desk': 6.7656203639192549,
#  'desktop': 5.9855993295769379,
#  'details': 8.0308367934859106,
#  'device': 6.0139863526592494,
#  'devices': 7.6712421394438426,
#  'dial': 6.6742182005121355,
#  'did': 7.6351660829700325,
#  'different': 7.3948480267659127,
#  'direct': 8.2026870504125675,
#  'directory': 7.9521445249102447,
#  'disabled': 8.1752880762244544,
#  'discharge': 7.7743376484708167,
#  'disk': 7.8446241811989887,
#  'display': 6.1970864225326174,
#  'displaying': 7.8206422165125034,
#  'distribution': 8.0250058731751164,
#  'dns': 7.7926029964481103,
#  'doc': 8.0192087554907907,
#  'docking': 7.9907167996964841,
#  'document': 6.7251944874473564,
#  'documentation': 8.0545065375718146,
#  'documents': 6.6697103040729457,
#  'does': 6.1970864225326174,
#  'doesnt': 7.1563431902902161,
#  'domain': 7.5630285548036094,
#  'dont': 7.57778897038673,
#  'dose': 8.3283132635299779,
#  'download': 7.041273860505429,
#  'downloading': 8.2821512217668154,
#  'downtime': 8.3126879456268981,
#  'dr': 6.0634382143013967,
#  'dragon': 8.2746605500376589,
#  'drawer': 7.3406178727050531,
#  'drive': 5.3452594482357583,
#  'driver': 7.7519653507162838,
#  'drives': 6.4249138231592537,
#  'drop': 8.2821512217668154,
#  'drug': 8.0605125616320272,
#  'duo': 4.138777831889664,
#  'duplicate': 7.7926029964481103,
#  'dw': 8.0849040147561855,
#  'eaf': 7.355389190025365,
#  'ed': 7.4957465477202874,
#  'edit': 6.0031503333179694,
#  'edw': 7.7519653507162838,
#  'efb': 5.2759476483455297,
#  'efbpb': 7.7300826394667759,
#  'email': 4.9437895511948824,
#  'emails': 6.8374460984905108,
#  'employee': 5.880163173814692,
#  'employees': 7.0834554745417231,
#  'enable': 7.9046421909252418,
#  'encounter': 7.0197676552844648,
#  'encounters': 8.1035961477683376,
#  'encryption': 6.5821993017918832,
#  'end': 7.3524174196362075,
#  'enrollment': 7.3347699028226296,
#  'enter': 7.968493662911774,
#  'entered': 8.1420624285961338,
#  'entry': 8.1820677632098331,
#  'environment': 7.9963506174147403,
#  'epic': 3.2414949114157023,
#  'equipment': 6.9842362269059794,
#  'error': 4.5241034729569876,
#  'errors': 6.8977383287466303,
#  'ethernet': 7.9907167996964841,
#  'exam': 7.3060322930552726,
#  'excel': 7.4073092472037247,
#  'exception': 7.2114950103652964,
#  'exchange': 7.73877834643433,
#  'existing': 8.091095985004106,
#  'export': 7.8691954419294934,
#  'external': 7.6877034164979143,
#  'facilities': 7.4424005670149951,
#  'factor': 6.8445635662593745,
#  'faculty': 8.0192087554907907,
#  'failed': 7.0478169590943649,
#  'failure': 8.1957666075679949,
#  'family': 7.7743376484708167,
#  'farmington': 7.4010592268585533,
#  'fax': 6.4390984581512098,
#  'faxes': 8.2308579273792652,
#  'fee': 7.6631120133605926,
#  'fhc': 7.5666982836925722,
#  'field': 7.5484828438012306,
#  'file': 6.3959933576163861,
#  'files': 6.7639715589290708,
#  'fix': 7.2919673635878688,
#  'fixed': 8.0426016350654947,
#  'flash': 7.3494544545055511,
#  'floor': 7.1539071354923349,
#  'flowsheet': 7.9521445249102447,
#  'fob': 7.9413917331339832,
#  'folder': 5.9855993295769379,
#  'folders': 7.4889205826498877,
#  'follow': 7.3465002426081192,
#  'following': 7.1514770006390433,
#  'form': 7.2063536108648778,
#  'forms': 8.2672255715501404,
#  'forward': 6.2707631433319957,
#  'forwarding': 6.8735511031326268,
#  'freezing': 7.0766757875563444,
#  'friday': 8.1035961477683376,
#  'froze': 7.7519653507162838,
#  'frozen': 5.4988122207208399,
#  'function': 8.0665548760879879,
#  'functioning': 7.968493662911774,
#  'fw': 6.6577876591160399,
#  'fwd': 8.0192087554907907,
#  'general': 5.2487900160193321,
#  'generate': 8.2380264168578776,
#  'generated': 6.5904752110957432,
#  'generic': 8.2746605500376589,
#  'getting': 6.3937154523033923,
#  'giving': 7.73877834643433,
#  'global': 8.1226443427390329,
#  'goes': 8.1486198291422927,
#  'going': 7.1346294300664317,
#  'gone': 8.0787501491818077,
#  'got': 8.2525194241604449,
#  'grant': 7.1204111810641528,
#  'granted': 7.7129148358444102,
#  'group': 5.9616818965163496,
#  'groups': 7.7519653507162838,
#  'guarantor': 8.3283132635299779,
#  'guardian': 8.1957666075679949,
#  'haiku': 8.1957666075679949,
#  'handler': 7.9521445249102447,
#  'hard': 7.6590716038235875,
#  'hardware': 6.8607655408356552,
#  'having': 6.5248119764252399,
#  'hb': 7.696036798057059,
#  'hc': 8.2525194241604449,
#  'hch': 7.4889205826498877,
#  'hci': 7.8206422165125034,
#  'health': 6.663731213016888,
#  'hear': 8.3850086072065224,
#  'help': 5.6730770593963413,
#  'hfs': 5.303863455804402,
#  'high': 7.4957465477202874,
#  'hire': 7.9795434990983587,
#  'hold': 7.9254762778280829,
#  'holding': 7.6590716038235875,
#  'home': 6.5196373206352227,
#  'hospital': 7.0544031519472217,
#  'host': 7.2698670165872032,
#  'hours': 8.1618650558923136,
#  'hp': 7.8349622702872512,
#  'hsc': 7.9740033187227439,
#  'httporion': 8.0367019129383088,
#  'huntsman': 7.5557292523219983,
#  'hwr': 7.8446241811989887,
#  'hyperspace': 7.8642326525873649,
#  'icon': 6.3394686172023693,
#  'icons': 7.968493662911774,
#  'id': 6.6214200149451647,
#  'idaho': 8.0250058731751164,
#  'im': 7.5026194270080495,
#  'image': 7.1087151413009613,
#  'images': 6.6878651143533174,
#  'imaging': 8.0787501491818077,
#  'imprivata': 8.0726339221643713,
#  'inactive': 7.3524174196362075,
#  'inbasket': 7.9907167996964841,
#  'inbox': 6.8717145553253252,
#  'incident': 7.6079799426658763,
#  'incorrect': 6.728369093288129,
#  'incorrectly': 8.1486198291422927,
#  'increase': 5.8754093448281512,
#  'increased': 7.5377107468193199,
#  'info': 7.034773295902335,
#  'information': 6.3128854463343673,
#  'infusion': 8.0250058731751164,
#  'initial': 8.1290752330693223,
#  'inpatient': 7.58900404120687,
#  'inquiry': 7.2975696191365387,
#  'install': 5.2793014804439604,
#  'installation': 7.1885640693013793,
#  'installed': 6.4462669476298231,
#  'installing': 8.2380264168578776,
#  'instead': 7.7519653507162838,
#  'instructions': 7.9202269219419392,
#  'insurance': 7.8065243349667179,
#  'interface': 7.2562982873811341,
#  'internal': 7.5026194270080495,
#  'internet': 6.4237408024968907,
#  'ip': 6.5484351221886756,
#  'ipad': 7.3764425992231972,
#  'iphone': 7.1986907381193079,
#  'isnt': 7.0766757875563444,
#  'isosa': 7.7171792346308683,
#  'issue': 4.4296068784764326,
#  'issues': 4.9640085982481885,
#  'item': 7.1110434310605521,
#  'items': 7.8206422165125034,
#  'jamming': 8.2452466648313649,
#  'java': 7.3825401790913165,
#  'job': 7.3032034368547949,
#  'johnson': 8.1752880762244544,
#  'jordan': 8.0077143760650564,
#  'july': 8.2380264168578776,
#  'just': 7.4687178753323682,
#  'keeps': 6.7739054154533616,
#  'key': 7.2808561381627985,
#  'keyboard': 6.8939789258227249,
#  'kiosk': 7.4521885733811581,
#  'know': 7.7044402088534385,
#  'kronos': 5.5626381490750152,
#  'lab': 6.5222213014011476,
#  'label': 6.4355333919867137,
#  'labels': 7.3856029686218614,
#  'labs': 8.091095985004106,
#  'landon': 7.7044402088534385,
#  'laptop': 5.3859485435598575,
#  'laptops': 8.2380264168578776,
#  'launch': 6.7001540554876691,
#  'launching': 7.4489152480361884,
#  'lawson': 7.2063536108648778,
#  'ldap': 8.2452466648313649,
#  'left': 8.091095985004106,
#  'let': 7.7171792346308683,
#  'letter': 7.9413917331339832,
#  'level': 7.968493662911774,
#  'license': 7.7129148358444102,
#  'light': 7.9630141971471486,
#  'like': 6.083257194961055,
#  'line': 6.4829010808096035,
#  'lines': 8.0308367934859106,
#  'link': 6.4028583731360662,
#  'linked': 8.1035961477683376,
#  'linking': 7.7972219423044047,
#  'links': 8.2026870504125675,
#  'list': 5.8493296320450998,
#  'listed': 7.1785389226820007,
#  'lists': 7.9046421909252418,
#  'live': 7.129867516306188,
#  'lms': 5.5527761362058996,
#  'load': 6.9699648328006472,
#  'loading': 7.0155213644030141,
#  'loc': 7.9413917331339832,
#  'local': 7.696036798057059,
#  'location': 7.129867516306188,
#  'locations': 8.2525194241604449,
#  'lock': 7.2192570157007854,
#  'locked': 5.7941166369918546,
#  'lockout': 6.4607599549323895,
#  'log': 5.3867794534539453,
#  'logged': 7.8741829834405328,
#  'logging': 7.1563431902902161,
#  'logic': 7.4653900852396937,
#  'login': 4.8457415354768365,
#  'logon': 8.1752880762244544,
#  'long': 8.0605125616320272,
#  'longer': 6.4379086900156217,
#  'look': 8.0250058731751164,
#  'lost': 7.2891779615002905,
#  'low': 8.0192087554907907,
#  'mac': 6.383528606996399,
#  'macbook': 8.0308367934859106,
#  'machine': 6.3801559225177602,
#  'machines': 8.1752880762244544,
#  'madsen': 8.1099053169616013,
#  'mail': 6.1594845603489397,
#  'mailbox': 6.1103087177020132,
#  'mailing': 8.2166732923873091,
#  'main': 7.3825401790913165,
#  'maintenance': 8.1618650558923136,
#  'make': 6.857142348466235,
#  'making': 8.1420624285961338,
#  'management': 6.9740216334962613,
#  'manager': 6.8958568606469255,
#  'map': 7.8741829834405328,
#  'mapping': 6.9034040662823077,
#  'master': 7.8995007914248223,
#  'md': 7.6391108612610497,
#  'med': 6.6712106794481807,
#  'media': 7.8642326525873649,
#  'medicaid': 7.696036798057059,
#  'medical': 7.6794389066480209,
#  'medicare': 8.1420624285961338,
#  'medication': 7.2063536108648778,
#  'medications': 8.2525194241604449,
#  'medicine': 7.7698229681162898,
#  'meeting': 6.8698813742436649,
#  'memory': 8.1099053169616013,
#  'message': 6.0480220874951458,
#  'messages': 7.193614585087448,
#  'messaging': 8.0973265347547425,
#  'meval': 7.9907167996964841,
#  'michael': 8.0726339221643713,
#  'microsoft': 7.4104489672083922,
#  'minutes': 8.2525194241604449,
#  'missing': 5.0656843110415171,
#  'mobile': 7.0994558158881649,
#  'modifier': 7.419927711162936,
#  'modifiers': 7.482140895664509,
#  'module': 7.5060736618761377,
#  'modules': 7.6712421394438426,
#  'monday': 8.2452466648313649,
#  'monitor': 5.812396376999418,
#  'monitoring': 7.5412885681672037,
#  'monitors': 7.2947645682089304,
#  'moran': 7.4889205826498877,
#  'morning': 8.0192087554907907,
#  'mouse': 6.92445747548014,
#  'moved': 7.2114950103652964,
#  'moving': 8.0665548760879879,
#  'mrn': 8.0308367934859106,
#  'ms': 8.2380264168578776,
#  'multi': 6.9015119181302698,
#  'multiple': 7.0176422559721514,
#  'muse': 8.0849040147561855,
#  'mychart': 6.6445424323660189,
#  'names': 8.2746605500376589,
#  'navigation': 7.2218577974008422,
#  'ndc': 8.3283132635299779,
#  'need': 3.9074824167216908,
#  'needed': 5.4872567420127361,
#  'needing': 7.854380356144353,
#  'needs': 4.5574547584048268,
#  'network': 5.1911087684085002,
#  'new': 4.1029174157286494,
#  'node': 6.6300283894817653,
#  'non': 7.4653900852396937,
#  'note': 6.6387115120552256,
#  'notes': 6.8753910300546339,
#  'notification': 7.9413917331339832,
#  'notified': 8.0726339221643713,
#  'npi': 7.9413917331339832,
#  'number': 6.1585848751780414,
#  'numbers': 8.0665548760879879,
#  'nurse': 7.3643578600081261,
#  'nurses': 7.9254762778280829,
#  'nursing': 7.3583698181635029,
#  'o365': 7.3948480267659127,
#  'ob': 8.3204700860689513,
#  'office': 6.0824235142124774,
#  'offline': 7.0456311658743846,
#  'old': 6.9167503082352022,
#  'omnicell': 7.4720567765978831,
#  'onbase': 7.2589973443502993,
#  'onboarding': 8.2746605500376589,
#  'onenote': 8.2096557197286621,
#  'online': 6.5835738724550499,
#  'op': 7.6671688140562066,
#  'open': 5.8754093448281512,
#  'opening': 7.0155213644030141,
#  'option': 7.261703705948042,
#  'options': 7.7880052871994803,
#  'oracle': 7.9795434990983587,
#  'order': 5.8727029832304085,
#  'orders': 6.3790342174085604,
#  'org': 7.9254762778280829,
#  'orion': 6.5365537943019234,
#  'ortho': 8.2598454642525176,
#  'outage': 7.9963506174147403,
#  'outlook': 4.6107162752444566,
#  'outpatient': 7.778872803636208,
#  'outside': 7.5815133694777126,
#  'overseas': 7.854380356144353,
#  'owa': 8.1355477475749396,
#  'owner': 7.8842333192940339,
#  'package': 8.1820677632098331,
#  'pacs': 5.6430938921515574,
#  'page': 6.4522801948532749,
#  'pages': 7.9046421909252418,
#  'paging': 8.0545065375718146,
#  'paper': 8.1552205131736457,
#  'password': 4.4882684586428949,
#  'past': 7.6590716038235875,
#  'patient': 5.0453911646421945,
#  'patients': 6.2597575294953938,
#  'payer': 7.8691954419294934,
#  'payroll': 7.8301660980237582,
#  'pb': 4.6631377376875207,
#  'pbefb': 7.6590716038235875,
#  'pc': 6.0618042270097421,
#  'pcs': 7.7972219423044047,
#  'pdf': 7.3948480267659127,
#  'people': 7.8349622702872512,
#  'peoplesoft': 6.7157306944164059,
#  'performance': 8.2166732923873091,
#  'permissions': 7.2698670165872032,
#  'personal': 7.4787682111858702,
#  'peter': 7.700229676317095,
#  'pfs': 7.8791955252640768,
#  'pgp': 6.4307996553365152,
#  'pharmacy': 6.9679425874198788,
#  'phi': 7.482140895664509,
#  'phishing': 7.3703819746115062,
#  'phoenix': 8.2672255715501404,
#  'phone': 4.5652836559247429,
#  'phones': 7.1986907381193079,
#  'phoneset': 7.5965512468422531,
#  'phrase': 8.2026870504125675,
#  'physical': 8.0250058731751164,
#  'physician': 7.7608542981335296,
#  'pick': 7.9202269219419392,
#  'pin': 7.0994558158881649,
#  'place': 8.0077143760650564,
#  'plan': 7.331858692615171,
#  'plans': 8.1888937282802328,
#  'player': 8.1820677632098331,
#  'pm': 8.2598454642525176,
#  'polling': 6.9760562221940488,
#  'polycom': 7.3145671955051101,
#  'pool': 7.0478169590943649,
#  'pools': 8.0726339221643713,
#  'pop': 8.1035961477683376,
#  'port': 6.4486679091673613,
#  'portal': 7.2919673635878688,
#  'ports': 7.7698229681162898,
#  'possible': 7.3886751676588318,
#  'post': 8.0077143760650564,
#  'potf': 5.9750649958919784,
#  'power': 6.9883514590510867,
#  'powerchart': 7.7300826394667759,
#  'powerscribe': 8.1486198291422927,
#  'ppid': 7.8691954419294934,
#  'practice': 8.1752880762244544,
#  'pre': 7.9046421909252418,
#  'preference': 8.1420624285961338,
#  'primary': 7.6590716038235875,
#  'print': 5.7212586650008932,
#  'printer': 4.4996718670408828,
#  'printers': 7.1017626219860794,
#  'printing': 5.7172018643052791,
#  'prior': 7.756399947784149,
#  'pro': 7.3231755700417107,
#  'problem': 6.7508780821820515,
#  'problems': 6.6143025471763011,
#  'procedure': 7.3231755700417107,
#  'process': 7.9851145441478142,
#  'profile': 6.7476313260831819,
#  'program': 6.8339062717853869,
#  'programs': 8.1290752330693223,
#  'progress': 8.2380264168578776,
#  'project': 6.9883514590510867,
#  'properly': 7.3979488044441615,
#  'provided': 8.2598454642525176,
#  'provider': 4.9127833889670471,
#  'providers': 6.1442989179305654,
#  'provisioning': 8.2166732923873091,
#  'pt': 6.7739054154533616,
#  'pull': 7.2863963185384133,
#  'pulling': 7.5630285548036094,
#  'pulse': 5.8092207630255315,
#  'push': 6.4705399839860291,
#  'pw': 8.2166732923873091,
#  'qradar': 7.4720567765978831,
#  'quality': 8.2672255715501404,
#  'question': 5.1836180966793419,
#  'questions': 6.8698813742436649,
#  'queue': 7.3917568341962401,
#  'quota': 5.7663969687515548,
#  'radiant': 6.7157306944164059,
#  'radiology': 7.7044402088534385,
#  'rdp': 7.4167581364016577,
#  'reactivate': 7.7044402088534385,
#  'reactivation': 7.0112930282934931,
#  'reactivtion': 7.8741829834405328,
#  'read': 8.1162545446402614,
#  'reading': 8.1035961477683376,
#  'reboot': 7.8691954419294934,
#  'receive': 7.6918614266465779,
#  'received': 7.9360583871586199,
#  'receiver': 6.2952042784911413,
#  'receiving': 7.1636871645459745,
#  'record': 7.193614585087448,
#  'recording': 8.1888937282802328,
#  'records': 7.4889205826498877,
#  'recovery': 7.7171792346308683,
#  'redwood': 8.1957666075679949,
#  'referral': 7.2644174118196387,
#  'referring': 7.3613593570118692,
#  'refill': 8.4451125312762301,
#  'registration': 6.4916456711983548,
#  'rehab': 8.0485363705853104,
#  'reimage': 7.6079799426658763,
#  'relationship': 7.9307533349289274,
#  'release': 7.482140895664509,
#  'reminder': 7.9630141971471486,
#  'remote': 6.6387115120552256,
#  'removal': 6.7460118925308787,
#  'remove': 5.6664581714704472,
#  'removed': 6.5524271434582131,
#  'repair': 7.7044402088534385,
#  'replace': 7.2323290972681384,
#  'replaced': 7.3231755700417107,
#  'replacement': 6.7363499816191421,
#  'report': 5.8232695253752347,
#  'reporting': 7.7519653507162838,
#  'reports': 6.3779137691120704,
#  'request': 4.1378237471422743,
#  'requested': 7.3764425992231972,
#  'requester': 7.1636871645459745,
#  'requesting': 6.4202299738468271,
#  'requestor': 8.1099053169616013,
#  'requests': 7.261703705948042,
#  'required': 6.4853917421220553,
#  'requires': 7.7926029964481103,
#  'research': 7.8943856907580523,
#  'reset': 4.4942092382300043,
#  'resident': 8.2973030267874179,
#  'resolution': 7.6835626238318833,
#  'resolved': 7.854380356144353,
#  'resource': 6.8111978724155744,
#  'responding': 7.6671688140562066,
#  'result': 8.1226443427390329,
#  'results': 7.1785389226820007,
#  'retire': 8.2308579273792652,
#  'return': 7.7519653507162838,
#  'returned': 7.6753321246953679,
#  'review': 6.0031503333179694,
#  'right': 7.4391590730908241,
#  'rights': 4.9035121404819133,
#  'rm': 8.2821512217668154,
#  'rn': 8.2746605500376589,
#  'roach': 8.0192087554907907,
#  'room': 5.7513228213931757,
#  'rooms': 7.4327074378093352,
#  'rounding': 5.376442375672446,
#  'route': 6.1496322639059278,
#  'router': 7.6835626238318833,
#  'routing': 7.3088691743904723,
#  'rsa': 4.6372707960862334,
#  'rule': 6.6986096536362947,
#  'rules': 8.1420624285961338,
#  'run': 7.3613593570118692,
#  'running': 7.1961494406906352,
#  'rx': 8.1290752330693223,
#  'save': 7.8943856907580523,
#  'saying': 8.0250058731751164,
#  'says': 7.0699417553750008,
#  'scan': 7.2012385101981069,
#  'scanned': 8.0020163549504169,
#  'scanner': 5.8092207630255315,
#  'scanners': 8.2096557197286621,
#  'scanning': 7.2482445525740378,
#  'schedule': 6.5287106168408977,
#  'scheduled': 7.9098101610836835,
#  'scheduling': 5.6430938921515574,
#  'schema': 8.2672255715501404,
#  'screen': 5.9254197654028129,
#  'search': 7.4991770828170772,
#  'second': 8.0367019129383088,
#  'section': 7.8741829834405328,
#  'secure': 8.0308367934859106,
#  'security': 6.7460118925308787,
#  'select': 8.1957666075679949,
#  'self': 8.1486198291422927,
#  'send': 5.8079533357329272,
#  'sending': 6.7236109558417123,
#  'sent': 7.0566082245055357,
#  'ser': 4.8660281898879845,
#  'server': 6.0376094984226851,
#  'servers': 7.0197676552844648,
#  'service': 6.1425274382821833,
#  'servicenow': 7.7129148358444102,
#  'services': 6.5339325608220493,
#  'session': 5.8375184711167556,
#  'set': 5.1116445970542532,
#  'setting': 6.8535322362421347,
#  'settings': 7.4687178753323682,
#  'setup': 5.2055668515837299,
#  'share': 7.4720567765978831,
#  'shared': 5.7224207801810705,
#  'showing': 6.2226438949877974,
#  'shows': 7.7608542981335296,
#  'sign': 5.8499899159911752,
#  'signal': 8.0308367934859106,
#  'signature': 8.168554044043109,
#  'site': 6.2931445455281301,
#  'size': 7.2780975157237187,
#  'sjhc': 6.8499351100612857,
#  'skype': 5.6522657935139415,
#  'slow': 6.70635562575095,
#  'slowness': 8.1486198291422927,
#  'small': 8.1099053169616013,
#  'smart': 7.3524174196362075,
#  'sms': 7.8112081842791445,
#  'software': 5.6388066401399373,
#  'som': 7.8842333192940339,
#  'sound': 7.6510394321263231,
#  'south': 7.6877034164979143,
#  'space': 6.7957734020899423,
#  'specialty': 8.0308367934859106,
#  'specific': 8.1099053169616013,
#  'spreadsheet': 7.8253928192711006,
#  'ss': 7.4620733326137003,
#  'staff': 7.2644174118196387,
#  'start': 7.3231755700417107,
#  'starting': 8.2166732923873091,
#  'states': 7.5095398698526239,
#  'static': 8.0250058731751164,
#  'station': 6.9904154432719379,
#  'status': 6.5030022601306907,
#  'stop': 7.9795434990983587,
#  'stopped': 7.7698229681162898,
#  'storage': 7.3613593570118692,
#  'stuck': 7.2037927900032042,
#  'student': 7.0369354589068305,
#  'studentsystemsutahedu': 8.1290752330693223,
#  'study': 7.6918614266465779,
#  'sublette': 7.1961494406906352,
#  'sup': 8.2237404596104007,
#  'supervisor': 8.0367019129383088,
#  'support': 7.3583698181635029,
#  'sure': 7.9360583871586199,
#  'surface': 7.8642326525873649,
#  'surgery': 7.6712421394438426,
#  'svp': 8.1486198291422927,
#  'switch': 7.7257629783222592,
#  'sx1': 8.2026870504125675,
#  'symantec': 6.8958568606469255,
#  'sync': 7.6312368048301433,
#  'syngo': 8.0426016350654947,
#  'tab': 7.0566082245055357,
#  'table': 7.721461896422869,
#  'tapes': 7.7300826394667759,
#  'task': 7.355389190025365,
#  'taxonomy': 8.2166732923873091,
#  'tc': 7.5593722436004995,
#  'team': 4.9260665638282051,
#  'tech': 7.9254762778280829,
#  'telephone': 7.8253928192711006,
#  'telestroke': 8.0849040147561855,
#  'teletracking': 7.574078390990195,
#  'temp': 6.0202314939560306,
#  'template': 6.8321410462608174,
#  'templates': 8.1752880762244544,
#  'temporary': 7.4424005670149951,
#  'test': 6.3014090553780235,
#  'testing': 6.8846417898267847,
#  'text': 7.9521445249102447,
#  'thank': 7.1394141281897676,
#  'thanks': 7.0070824957571496,
#  'therapy': 7.4359280525093778,
#  'ticket': 6.2036499716466214,
#  'tier': 6.9558942489037046,
#  'tile': 8.2380264168578776,
#  'time': 5.1718155654738212,
#  'times': 7.5965512468422531,
#  'toad': 8.2672255715501404,
#  'today': 7.2753464823518286,
#  'token': 5.675847911820286,
#  'tone': 6.8060299022571318,
#  'toner': 6.5339325608220493,
#  'tool': 7.8691954419294934,
#  'tower': 7.9795434990983587,
#  'tracking': 8.091095985004106,
#  'training': 6.3756766317137137,
#  'transfer': 6.9639103238919411,
#  'transplant': 8.0973265347547425,
#  'tried': 7.9046421909252418,
#  'trouble': 6.7839389444429399,
#  'troubleshooting': 8.1035961477683376,
#  'trust': 7.8301660980237582,
#  'try': 8.01344505077404,
#  'trying': 6.4486679091673613,
#  'tst': 7.5095398698526239,
#  'turn': 7.034773295902335,
#  'turning': 8.0545065375718146,
#  'type': 6.2121526208872622,
#  'types': 7.0391023069919205,
#  'ubox': 7.4554726485823481,
#  'uconnect': 6.345955126431976,
#  'uguest': 7.3494544545055511,
#  'uid': 7.8018623218609067,
#  'uit': 7.2698670165872032,
#  'umail': 4.5214758109388118,
#  'umb': 6.3170915513786419,
#  'unable': 4.1260916696947501,
#  'unenroll': 7.854380356144353,
#  'uni': 7.2140756569587881,
#  'unid': 7.2698670165872032,
#  'unit': 7.6351660829700325,
#  'university': 6.5618043052708099,
#  'unlock': 7.1961494406906352,
#  'update': 4.4184974164943078,
#  'updated': 5.972822004297397,
#  'updates': 6.92445747548014,
#  'updating': 6.7689261520537549,
#  'upgrade': 6.8077495931366583,
#  'upload': 8.1888937282802328,
#  'urgent': 7.8943856907580523,
#  'urology': 8.2746605500376589,
#  'usa': 8.2308579273792652,
#  'usage': 6.6387115120552256,
#  'use': 6.5068166322061609,
#  'used': 7.482140895664509,
#  'user': 4.296933657998018,
#  'users': 6.0296729488269492,
#  'using': 6.7508780821820515,
#  'utah': 7.8842333192940339,
#  'utap': 8.01344505077404,
#  'uuhc': 8.091095985004106,
#  'vdi': 7.6877034164979143,
#  'vendor': 7.127495035952558,
#  'verification': 6.857142348466235,
#  'verify': 7.7653285785284503,
#  'version': 7.696036798057059,
#  'video': 7.756399947784149,
#  'vidyo': 7.3917568341962401,
#  'view': 6.54976402603873,
#  'violation': 7.3174284277861421,
#  'virus': 8.1162545446402614,
#  'visio': 8.2672255715501404,
#  'visit': 5.7972445719788155,
#  'vlan': 8.0545065375718146,
#  'vm': 7.6351660829700325,
#  'vocera': 7.2063536108648778,
#  'voice': 8.0726339221643713,
#  'voicemail': 7.1961494406906352,
#  'vpn': 6.3003722486495839,
#  'walked': 6.0093279591419266,
#  'wall': 8.3049658995329878,
#  'wants': 6.7395602572493898,
#  'warehouse': 7.3088691743904723,
#  'warning': 8.1162545446402614,
#  'way': 8.2525194241604449,
#  'web': 6.3914427240523901,
#  'website': 7.0304629444012132,
#  'week': 7.9630141971471486,
#  'welcome': 8.1957666075679949,
#  'wellness': 8.1355477475749396,
#  'west': 8.0787501491818077,
#  'white': 8.168554044043109,
#  'whitelist': 7.721461896422869,
#  'wifi': 7.3347699028226296,
#  'willow': 6.4120856589051414,
#  'window': 8.2452466648313649,
#  'windows': 6.240052458416061,
#  'wireless': 7.034773295902335,
#  'wont': 6.0626208869162985,
#  'word': 8.0077143760650564,
#  'work': 5.8271355095717006,
#  'working': 4.5783461174362037,
#  'works': 8.2452466648313649,
#  'workstation': 6.3014090553780235,
#  'wow': 7.6712421394438426,
#  'wq': 5.7810851153132115,
#  'wqs': 7.6156722882890318,
#  'wrong': 6.4355333919867137,
#  'zebra': 7.574078390990195}

# %% [markdown]
# ## Clustering using k-means

# %%
true_k = 20
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=20, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ## Human readable clusters

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print( "Cluster %d:" % i, end=" ")
    for ind in order_centroids[i, :20]:
        print(' %s' % terms[ind], end=" ")
    print('\n')
# Out:
# Top terms per cluster:
# Cluster 0:  duo  question  general  bypass  code  generated  setup  reactivation  authenticate  caller  task  unable  set  token  request  reactivtion  reactivate  enrollment  information  device
#
# Cluster 1:  umail  quota  increase  request  alias  lockout  account  locked  unlock  cleared  mailbox  display  change  issue  forwarding  increased  administer  behalf  created  users
#
# Cluster 2:  issues  outlook  computer  printer  having  citrix  monitor  login  epic  connectivity  connection  network  printing  phone  kronos  laptop  lms  skype  display  receiver
#
# Cluster 3:  data  warehouse  bi  report  access  need  request  table  port  updated  center  new  team  boe  epic  reports  research  missing  edw  toad
#
# Cluster 4:  access  epic  need  request  unable  peoplesoft  kronos  wants  drive  pulse  folder  remote  grant  umb  shared  network  citrix  employee  vpn  granted
#
# Cluster 5:  epic  hfs  team  scheduling  issue  unable  icon  visit  add  provider  log  need  account  change  missing  willow  new  printing  ser  error
#
# Cluster 6:  password  reset  computer  need  issue  new  error  request  working  citrix  unable  email  missing  add  potf  patient  change  network  account  drive
#
# Cluster 7:  printer  printing  label  add  print  working  error  issue  toner  zebra  epic  need  computer  mapping  set  request  default  network  installation  jamming
#
# Cluster 8:  rights  admin  temp  request  need  install  software  temporary  computer  needed  update  download  requesting  laptop  rounding  pc  needs  dragon  right  barcode
#
# Cluster 9:  needs  updated  ser  pb  access  user  added  new  epic  computer  updating  installed  changed  employee  replaced  printer  set  laptop  dr  provider
#
# Cluster 10:  outlook  error  unable  issue  open  log  setup  calendar  email  working  sign  access  set  skype  shared  opening  need  2016  missing  mailbox
#
# Cluster 11:  pb  efb  update  ser  review  edit  charge  cr  rule  ss  epic  brenda  wq  route  area  needed  densley  handler  new  fee
#
# Cluster 12:  update  ser  provider  radiant  epic  wq  master  request  information  address  need  email  plan  alias  citrix  payer  team  needed  flash  software
#
# Cluster 13:  login  time  outlook  cis  unable  error  epic  skype  lms  user  citrix  duo  initial  credentials  umail  issue  unid  university  service  pgp
#
# Cluster 14:  rounding  client  assisted  asked  navigation  services  applications  university  web  windows  10  clients  updating  user  floor  bsb  configuring  computer  help  requester
#
# Cluster 15:  rsa  token  removal  setup  software  pin  hardware  unenroll  request  deactivate  duo  activation  vendor  set  2fa  overseas  enrollment  reset  remove  delivery
#
# Cluster 16:  user  walked  compromised  account  duo  unable  setup  access  accessing  sending  phishing  uconnect  umail  device  epic  assisted  authenticate  setting  new  add
#
# Cluster 17:  assistance  sign  time  usage  multi  factor  required  registration  authentication  device  duo  user  account  administration  ubox  o365  accessing  student  mail  365
#
# Cluster 18:  phone  working  new  issue  duo  set  number  dial  avaya  tone  calls  line  polycom  setup  need  activate  rsa  801  skype  needs
#
# Cluster 19:  frozen  session  epic  citrix  computer  vdi  kronos  tc  workstation  client  screen  lawson  3m  error  media  tab  360  black  onbase  user
